# %% [markdown]
# # ChromaDb - Getting Started

# %% [markdown]
# Inspireret af: https://docs.trychroma.com/docs/overview/getting-started

# %% [markdown]
# Client

# %% [markdown]
# ### Http client

# %%
import chromadb

# Initialize the ChromaDB client and connect to the Docker instance
client = chromadb.HttpClient(host="localhost", port=8000)

# Create or get a collection
#collection = client.create_collection(name="my_collection")

# Add documents to the collection
#collection.add(
#    documents=["This is a document about cats", "This is a document about dogs"],
#    metadatas=[{"category": "animal"}, {"category": "animal"}],
#    ids=["id1", "id2"]
#)

# Query the collection
results = collection.query(
    query_texts=["dogs?"],
    n_results=1
)

# Print the results
print("Query results:", results)
# Out:
# Query results: {'ids': [['id2']], 'distances': [[0.98015046]], 'embeddings': None, 'metadatas': [[{'category': 'animal'}]], 'documents': [['This is a document about dogs']], 'uris': None, 'data': None, 'included': ['metadatas', 'documents', 'distances']}
