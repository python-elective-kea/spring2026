# %% [markdown]
# # filer

# %%
import sqlite3
conn = sqlite3.connect('database.db')
cur = conn.cursor()
cur.execute('''
    CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    email TEXT UNIQUE NOT NULL,
    age INTEGER,
    created_date TEXT DEFAULT CURRENT_TIMESTAMP)''')

# %%
f = open('xxx.txt', 'a')
f.write('Hello heloo\n')
# Out:
# 12

# %%
with open('xxx.txt', 'r') as f:
    print(f.read())
# Out:
# Hello helooHello helooHello helooHello helooHello helooHello heloo
# Hello heloo
# Hello heloo
# Hello heloo
# Hello heloo
# Hello heloo
# Hello heloo
# Hello heloo
# Hello heloo

# %% [markdown]
# # Moduler

# %% [markdown]
# ## OS

# %%
import os  # ikke pip intstalles


#os.chdir('ooo')
open('test.md', 'w')
os.listdir()
os.makedirs('ppppp', exist_ok=True)

# %% [markdown]
# ## subprocess

# %%
# preferred
os.makedirs('lll', exist_ok=True)

# or with subprocess on Windows
# subprocess.run('mkdir lll', shell=True, check=True)
# or
# subprocess.run(['cmd', '/c', 'mkdir', 'lll'], check=True)

# %% [markdown]
# ## requests

# %%
import requests  
  
api_key = os.environ.get('API_KEY')
url = 'https://api.github.com/repos/clbokea/osman'

headers = {
        'Authorization': f'token xxx'
}
response = requests.get(url, headers=headers)
repo_data = response.json()
response.status_code
# Out:
# 401

# %%
repo_data
# Out:
# {'message': 'Bad credentials',
#  'documentation_url': 'https://docs.github.com/rest',
#  'status': '401'}
