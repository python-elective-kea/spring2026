# %% [markdown]
# # Arbejd med filer i Python

# %% [markdown]
# Her har du er overblik over hvordan man læser og skriver til filer i python.
# Jeg viser to måder for at læse og tilsvarende 2 måder for at skrive.

# %% [markdown]
# ## Læs fra filer

# %% [markdown]
# ### 1. Den basale måde

# %%
f = open('testfiles/bohr.txt', 'r')
f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f = open('testfiles/bohr.txt', 'r')
#       2 f.read()
#
# File c:\Users\lucas\Documents\GitHub\spring2026\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testfiles/bohr.txt'

# %% [markdown]
# ### 2. Med brug af `contextmanager protokollen`
#
# Denne metode sørger for at lukke de filer man åbner igen. Dette er god stil at gøre og det forhindre desuden også en masse potitentille problemer og sikkerheds brister (som feks. memory leaks).
# Denne metoder er altså den fortrukne.

# %%
with open('testfiles/bohr.txt', 'r') as f:
    print(f.read())
    # print(f.readline())
    # print(f.readlines())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 with open('testfiles/bohr.txt', 'r') as f:
#       2     print(f.read())
#       3     # print(f.readline())
#       4     # print(f.readlines())
#
# File c:\Users\lucas\Documents\GitHub\spring2026\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testfiles/bohr.txt'

# %% [markdown]
# ## Skriv til filer

# %% [markdown]
# ### 1. Den basale måde

# %%
f = open('testfiles/test.txt', 'w')
f.write('Hello world!')
# Out:
# 12

# %% [markdown]
# ### 2. Med brug af `contextmanager protokollen`

# %%
with open('testfiles/test.txt', 'w') as f:
    f.write('Hello world')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 with open('testfiles/test.txt', 'w') as f:
#       2     f.write('Hello world')
#
# File c:\Users\lucas\Documents\GitHub\spring2026\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testfiles/test.txt'
